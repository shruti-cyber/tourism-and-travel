# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
pd.options.mode.chained_assignment = None

# read the data
df = pd.read_csv('cultural-spaces.csv',sep = ';')


# Modified the Data Frame by Removing unwanted Columns
df = df[['YEAR','CULTURAL_SPACE_NAME','WEBSITE','TYPE','PRIMARY_USE','ADDRESS','LOCAL_AREA','OWNERSHIP','Geom']]
df
# Out:
#       YEAR                                CULTURAL_SPACE_NAME  \
# 0     2017                             221A Artist Run Centre
# 1     2017                              222 E Georgia Studios
# 2     2017  Aberthau Mansion/West Point Grey Community Centre
# 3     2017                      Alliance for Arts and Culture
# 4     2017                    Alliance Francaise de Vancouver
# ...    ...                                                ...
# 1937  2020                              Yuk Yuk's Comedy Club
# 1938  2017                                        221A - 1654
# 1939  2017   Another Space for Community Creative Arts Studio
# 1940  2017                                       Art Emporium
# 1941  2017                                   Artspeak Gallery
#
#                                WEBSITE                 TYPE  \
# 0                        www.221a.ca/?       Museum/Gallery
# 1         http://projectspace.ca/blog/     Studio/Rehearsal
# ...

# %%
df['randNumCol'] = pd.Series(random.choices(["https://firebasestorage.googleapis.com/v0/b/explorer-8b11d.appspot.com/o/1.jpg?alt=media&token=f4afc4cd-62f2-4c11-8a98-b947ab47113b",'https://firebasestorage.googleapis.com/v0/b/explorer-8b11d.appspot.com/o/10.jpg?alt=media&token=41d2a644-57b0-4be2-9652-6fbbd3c6059d','https://firebasestorage.googleapis.com/v0/b/explorer-8b11d.appspot.com/o/11.jpg?alt=media&token=97342afb-bc0a-4809-8520-87ee55083e7c','https://firebasestorage.googleapis.com/v0/b/explorer-8b11d.appspot.com/o/3.jpg?alt=media&token=bd6228bb-e568-42b3-a506-3a551b5e8255','https://firebasestorage.googleapis.com/v0/b/explorer-8b11d.appspot.com/o/2.jpg?alt=media&token=20660e42-c9d0-4193-b830-2af707367ed4'], k=df.shape[0]))

df
# Out:
#       YEAR                                CULTURAL_SPACE_NAME  \
# 0     2017                             221A Artist Run Centre
# 1     2017                              222 E Georgia Studios
# 2     2017  Aberthau Mansion/West Point Grey Community Centre
# 3     2017                      Alliance for Arts and Culture
# 4     2017                    Alliance Francaise de Vancouver
# ...    ...                                                ...
# 1937  2020                              Yuk Yuk's Comedy Club
# 1938  2017                                        221A - 1654
# 1939  2017   Another Space for Community Creative Arts Studio
# 1940  2017                                       Art Emporium
# 1941  2017                                   Artspeak Gallery
#
#                                WEBSITE                 TYPE  \
# 0                        www.221a.ca/?       Museum/Gallery
# 1         http://projectspace.ca/blog/     Studio/Rehearsal
# ...

# %%
df.rename(columns = {'CULTURAL_SPACE_NAME':'place_name','YEAR':'year', 'WEBSITE':'web_url','TYPE':'category','PRIMARY_USE':'primary_use','ADDRESS':'address','ADDRESS':'address','LOCAL_AREA':'city','OWNERSHIP':'ownership','Geom':'location','randNumCol':'image_url'}, inplace = True)
df
# Out:
#       year                                         place_name  \
# 0     2017                             221A Artist Run Centre
# 1     2017                              222 E Georgia Studios
# 2     2017  Aberthau Mansion/West Point Grey Community Centre
# 3     2017                      Alliance for Arts and Culture
# 4     2017                    Alliance Francaise de Vancouver
# ...    ...                                                ...
# 1937  2020                              Yuk Yuk's Comedy Club
# 1938  2017                                        221A - 1654
# 1939  2017   Another Space for Community Creative Arts Studio
# 1940  2017                                       Art Emporium
# 1941  2017                                   Artspeak Gallery
#
#                                web_url             category  \
# 0                        www.221a.ca/?       Museum/Gallery
# 1         http://projectspace.ca/blog/     Studio/Rehearsal
# ...

# %%
df['ratings'] = np.random.randint(1, 6, df.shape[0])
df
# Out:
#       year                                         place_name  \
# 0     2017                             221A Artist Run Centre
# 1     2017                              222 E Georgia Studios
# 2     2017  Aberthau Mansion/West Point Grey Community Centre
# 3     2017                      Alliance for Arts and Culture
# 4     2017                    Alliance Francaise de Vancouver
# ...    ...                                                ...
# 1937  2020                              Yuk Yuk's Comedy Club
# 1938  2017                                        221A - 1654
# 1939  2017   Another Space for Community Creative Arts Studio
# 1940  2017                                       Art Emporium
# 1941  2017                                   Artspeak Gallery
#
#                                web_url             category  \
# 0                        www.221a.ca/?       Museum/Gallery
# 1         http://projectspace.ca/blog/     Studio/Rehearsal
# ...

# %%
df['description'] = 'orem ipsum dolor sit amet, consectetuer adipiscing elit. Aenean commodo ligula eget dolor. Aenean massa. Cum sociis natoque penatibus et magnis dis parturient montes, nascetur ridiculus mus. Donec quam felis, ultricies nec, pellentesque eu, pretium quis, sem. Nulla consequat massa quis enim. Donec pede justo, fringilla vel, aliquet nec, vulputate eget, arcu. In enim justo, rhoncus ut, imperdiet a, venenatis vitae, justo. Nullam dictum felis eu pede mollis pretium. Integer tincidunt. Cras dapibus. Vivamus elementum semper nisi. Aenean vulputate eleifend tellus. Aenean leo ligula.'
df
# Out:
#       year                                         place_name  \
# 0     2017                             221A Artist Run Centre
# 1     2017                              222 E Georgia Studios
# 2     2017  Aberthau Mansion/West Point Grey Community Centre
# 3     2017                      Alliance for Arts and Culture
# 4     2017                    Alliance Francaise de Vancouver
# ...    ...                                                ...
# 1937  2020                              Yuk Yuk's Comedy Club
# 1938  2017                                        221A - 1654
# 1939  2017   Another Space for Community Creative Arts Studio
# 1940  2017                                       Art Emporium
# 1941  2017                                   Artspeak Gallery
#
#                                web_url             category  \
# 0                        www.221a.ca/?       Museum/Gallery
# 1         http://projectspace.ca/blog/     Studio/Rehearsal
# ...
